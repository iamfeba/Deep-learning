# %% [markdown]
# ## Sattellite Image classification

# %% [markdown]
# #### Import necessary libraries

# %%
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# #### Fetch the training Data

# %%
pwd
# Out:
# 'C:\\Users\\DHILSHANA SHIRIN\\Edure\\Deep learning\\Capstone projects\\Deep learning Capstone projects (1)\\Deep learning Capstone projects\\Sattellite Image classification\\data'

# %%
import glob

# %%
cloudy = glob.glob('train_data/cloudy/*.jpg')
desert = glob.glob('train_data/desert/*.jpg')
green_area = glob.glob('train_data/green_area/*.jpg')
water = glob.glob('train_data/water/*.jpg')

# %%
water
# Out:
# ['train_data/water\\SeaLake_1125.jpg',
#  'train_data/water\\SeaLake_1126.jpg',
#  'train_data/water\\SeaLake_1127.jpg',
#  'train_data/water\\SeaLake_1128.jpg',
#  'train_data/water\\SeaLake_1131.jpg',
#  'train_data/water\\SeaLake_1132.jpg',
#  'train_data/water\\SeaLake_1133.jpg',
#  'train_data/water\\SeaLake_1134.jpg',
#  'train_data/water\\SeaLake_1135.jpg',
#  'train_data/water\\SeaLake_1138.jpg',
#  'train_data/water\\SeaLake_1140.jpg',
#  'train_data/water\\SeaLake_1141.jpg',
#  'train_data/water\\SeaLake_1144.jpg',
#  'train_data/water\\SeaLake_1145.jpg',
#  'train_data/water\\SeaLake_1146.jpg',
#  'train_data/water\\SeaLake_1147.jpg',
#  'train_data/water\\SeaLake_1148.jpg',
#  'train_data/water\\SeaLake_1151.jpg',
#  'train_data/water\\SeaLake_1154.jpg',
#  'train_data/water\\SeaLake_1156.jpg',
#  'train_data/water\\SeaLake_1157.jpg',
#  'train_data/water\\SeaLake_1158.jpg',
#  'train_data/water\\SeaLake_1159.jpg',
#  'train_data/water\\SeaLake_1160.jpg',
#  'train_data/water\\SeaLake_1163.jpg',
#  'train_data/water\\SeaLake_1164.jpg',
#  'train_data/water\\SeaLake_1165.jpg',
#  'train_data/water\\SeaLake_1169.jpg',
#  'train_data/water\\SeaLake_1172.jpg',
#  'train_data/water\\SeaLake_1175.jpg',
#  'train_data/water\\SeaLake_1176.jpg',
#  'train_data/water\\SeaLake_1178.jpg',
#  'train_data/water\\SeaLake_1180.jpg',
#  'train_data/water\\SeaLake_1184.jpg',
#  'train_data/water\\SeaLake_1185.jpg',
#  'train_data/water\\SeaLake_1186.jpg',
#  'train_data/water\\SeaLake_1187.jpg',
#  'train_data/water\\SeaLake_1188.jpg',
#  'train_data/water\\SeaLake_1190.jpg',
#  'train_data/water\\SeaLake_1191.jpg',
#  'train_data/water\\SeaLake_1193.jpg',
#  'train_data/water\\SeaLake_1195.jpg',
#  'train_data/water\\SeaLake_1199.jpg',
#  'train_data/water\\SeaLake_1205.jpg',
#  'train_data/water\\SeaLake_1208.jpg',
#  'train_data/water\\SeaLake_1209.jpg',
#  'train_data/water\\SeaLake_1214.jpg',
#  'train_data/water\\SeaLake_1215.jpg',
#  'train_data/water\\SeaLake_1220.jpg',
#  'train_data/water\\SeaLake_1222.jpg',
#  'train_data/water\\SeaLake_1227.jpg',
#  'train_data/water\\SeaLake_1230.jpg',
#  'train_data/water\\SeaLake_1232.jpg',
#  'train_data/water\\SeaLake_1237.jpg',
#  'train_data/water\\SeaLake_1238.jpg',
#  'train_data/water\\SeaLake_1241.jpg',
#  'train_data/water\\SeaLake_1249.jpg',
#  'train_data/water\\SeaLake_1253.jpg',
#  'train_data/water\\SeaLake_1254.jpg',
#  'train_data/water\\SeaLake_1260.jpg',
#  'train_data/water\\SeaLake_1262.jpg',
#  'train_data/water\\SeaLake_1263.jpg',
#  'train_data/water\\SeaLake_1265.jpg',
#  'train_data/water\\SeaLake_1267.jpg',
#  'train_data/water\\SeaLake_1268.jpg',
#  'train_data/water\\SeaLake_1271.jpg',
#  'train_data/water\\SeaLake_1274.jpg',
#  'train_data/water\\SeaLake_1275.jpg',
#  'train_data/water\\SeaLake_1277.jpg',
#  'train_data/water\\SeaLake_1278.jpg',
#  'train_data/water\\SeaLake_1279.jpg',
#  'train_data/water\\SeaLake_1281.jpg',
#  'train_data/water\\SeaLake_1284.jpg',
#  'train_data/water\\SeaLake_1286.jpg',
#  'train_data/water\\SeaLake_1292.jpg',
#  'train_data/water\\SeaLake_1294.jpg',
#  'train_data/water\\SeaLake_1295.jpg',
#  'train_data/water\\SeaLake_1298.jpg',
#  'train_data/water\\SeaLake_1301.jpg',
#  'train_data/water\\SeaLake_1303.jpg',
#  'train_data/water\\SeaLake_1305.jpg',
#  'train_data/water\\SeaLake_1309.jpg',
#  'train_data/water\\SeaLake_1310.jpg',
#  'train_data/water\\SeaLake_1313.jpg',
#  'train_data/water\\SeaLake_1316.jpg',
#  'train_data/water\\SeaLake_1321.jpg',
#  'train_data/water\\SeaLake_1327.jpg',
#  'train_data/water\\SeaLake_1328.jpg',
#  'train_data/water\\SeaLake_1329.jpg',
#  'train_data/water\\SeaLake_1330.jpg',
#  'train_data/water\\SeaLake_1332.jpg',
#  'train_data/water\\SeaLake_1335.jpg',
#  'train_data/water\\SeaLake_1336.jpg',
#  'train_data/water\\SeaLake_1337.jpg',
#  'train_data/water\\SeaLake_1338.jpg',
#  'train_data/water\\SeaLake_1340.jpg',
#  'train_data/water\\SeaLake_1342.jpg',
#  'train_data/water\\SeaLake_1343.jpg',
#  'train_data/water\\SeaLake_1344.jpg',
#  'train_data/water\\SeaLake_1347.jpg',
#  'train_data/water\\SeaLake_1348.jpg',
#  'train_data/water\\SeaLake_1349.jpg',
#  'train_data/water\\SeaLake_1350.jpg',
#  'train_data/water\\SeaLake_1352.jpg',
#  'train_data/water\\SeaLake_1354.jpg',
#  'train_data/water\\SeaLake_1355.jpg',
#  'train_data/water\\SeaLake_1358.jpg',
#  'train_data/water\\SeaLake_1361.jpg',
#  'train_data/water\\SeaLake_1362.jpg',
#  'train_data/water\\SeaLake_1363.jpg',
#  'train_data/water\\SeaLake_1364.jpg',
#  'train_data/water\\SeaLake_1365.jpg',
#  'train_data/water\\SeaLake_1366.jpg',
#  'train_data/water\\SeaLake_1367.jpg',
#  'train_data/water\\SeaLake_1368.jpg',
#  'train_data/water\\SeaLake_1370.jpg',
#  'train_data/water\\SeaLake_1376.jpg',
#  'train_data/water\\SeaLake_1377.jpg',
#  'train_data/water\\SeaLake_1379.jpg',
#  'train_data/water\\SeaLake_1381.jpg',
#  'train_data/water\\SeaLake_1387.jpg',
#  'train_data/water\\SeaLake_1390.jpg',
#  'train_data/water\\SeaLake_1391.jpg',
#  'train_data/water\\SeaLake_1395.jpg',
#  'train_data/water\\SeaLake_1396.jpg',
#  'train_data/water\\SeaLake_1397.jpg',
#  'train_data/water\\SeaLake_1402.jpg',
#  'train_data/water\\SeaLake_1405.jpg',
#  'train_data/water\\SeaLake_1406.jpg',
#  'train_data/water\\SeaLake_1407.jpg',
#  'train_data/water\\SeaLake_1408.jpg',
#  'train_data/water\\SeaLake_1409.jpg',
#  'train_data/water\\SeaLake_1411.jpg',
#  'train_data/water\\SeaLake_1413.jpg',
#  'train_data/water\\SeaLake_1414.jpg',
#  'train_data/water\\SeaLake_1415.jpg',
#  'train_data/water\\SeaLake_1416.jpg',
#  'train_data/water\\SeaLake_1421.jpg',
#  'train_data/water\\SeaLake_1423.jpg',
#  'train_data/water\\SeaLake_1426.jpg',
#  'train_data/water\\SeaLake_1427.jpg',
#  'train_data/water\\SeaLake_1429.jpg',
#  'train_data/water\\SeaLake_1430.jpg',
#  'train_data/water\\SeaLake_1434.jpg',
#  'train_data/water\\SeaLake_1437.jpg',
#  'train_data/water\\SeaLake_1438.jpg',
#  'train_data/water\\SeaLake_1441.jpg',
#  'train_data/water\\SeaLake_1444.jpg',
#  'train_data/water\\SeaLake_1446.jpg',
#  'train_data/water\\SeaLake_1447.jpg',
#  'train_data/water\\SeaLake_1448.jpg',
#  'train_data/water\\SeaLake_1449.jpg',
#  'train_data/water\\SeaLake_1451.jpg',
#  'train_data/water\\SeaLake_1456.jpg',
#  'train_data/water\\SeaLake_1460.jpg',
#  'train_data/water\\SeaLake_1464.jpg',
#  'train_data/water\\SeaLake_1469.jpg',
#  'train_data/water\\SeaLake_1470.jpg',
#  'train_data/water\\SeaLake_1473.jpg',
#  'train_data/water\\SeaLake_1475.jpg',
#  'train_data/water\\SeaLake_1479.jpg',
#  'train_data/water\\SeaLake_1481.jpg',
#  'train_data/water\\SeaLake_1484.jpg',
#  'train_data/water\\SeaLake_1485.jpg',
#  'train_data/water\\SeaLake_1489.jpg',
#  'train_data/water\\SeaLake_1492.jpg',
#  'train_data/water\\SeaLake_1493.jpg',
#  'train_data/water\\SeaLake_1497.jpg',
#  'train_data/water\\SeaLake_1498.jpg',
#  'train_data/water\\SeaLake_1502.jpg',
#  'train_data/water\\SeaLake_1504.jpg',
#  'train_data/water\\SeaLake_1505.jpg',
#  'train_data/water\\SeaLake_1506.jpg',
#  'train_data/water\\SeaLake_1507.jpg',
#  'train_data/water\\SeaLake_1510.jpg',
#  'train_data/water\\SeaLake_1511.jpg',
#  'train_data/water\\SeaLake_1513.jpg',
#  'train_data/water\\SeaLake_1514.jpg',
#  'train_data/water\\SeaLake_1515.jpg',
#  'train_data/water\\SeaLake_1517.jpg',
#  'train_data/water\\SeaLake_1519.jpg',
#  'train_data/water\\SeaLake_1522.jpg',
#  'train_data/water\\SeaLake_1523.jpg',
#  'train_data/water\\SeaLake_1524.jpg',
#  'train_data/water\\SeaLake_1525.jpg',
#  'train_data/water\\SeaLake_1527.jpg',
#  'train_data/water\\SeaLake_1530.jpg',
#  'train_data/water\\SeaLake_1531.jpg',
#  'train_data/water\\SeaLake_1533.jpg',
#  'train_data/water\\SeaLake_1536.jpg',
#  'train_data/water\\SeaLake_1537.jpg',
#  'train_data/water\\SeaLake_1538.jpg',
#  'train_data/water\\SeaLake_1541.jpg',
#  'train_data/water\\SeaLake_1546.jpg',
#  'train_data/water\\SeaLake_1547.jpg',
#  'train_data/water\\SeaLake_1549.jpg',
#  'train_data/water\\SeaLake_1551.jpg',
#  'train_data/water\\SeaLake_1552.jpg',
#  'train_data/water\\SeaLake_1553.jpg',
#  'train_data/water\\SeaLake_1554.jpg',
#  'train_data/water\\SeaLake_1556.jpg',
#  'train_data/water\\SeaLake_1558.jpg',
#  'train_data/water\\SeaLake_1559.jpg',
#  'train_data/water\\SeaLake_1562.jpg',
#  'train_data/water\\SeaLake_1563.jpg',
#  'train_data/water\\SeaLake_1564.jpg',
#  'train_data/water\\SeaLake_1566.jpg',
#  'train_data/water\\SeaLake_1569.jpg',
#  'train_data/water\\SeaLake_1575.jpg',
#  'train_data/water\\SeaLake_1576.jpg',
#  'train_data/water\\SeaLake_1577.jpg',
#  'train_data/water\\SeaLake_1584.jpg',
#  'train_data/water\\SeaLake_1585.jpg',
#  'train_data/water\\SeaLake_1586.jpg',
#  'train_data/water\\SeaLake_1587.jpg',
#  'train_data/water\\SeaLake_1588.jpg',
#  'train_data/water\\SeaLake_1590.jpg',
#  'train_data/water\\SeaLake_1592.jpg',
#  'train_data/water\\SeaLake_1594.jpg',
#  'train_data/water\\SeaLake_1595.jpg',
#  'train_data/water\\SeaLake_1599.jpg',
#  'train_data/water\\SeaLake_1601.jpg',
#  'train_data/water\\SeaLake_1605.jpg',
#  'train_data/water\\SeaLake_1606.jpg',
#  'train_data/water\\SeaLake_1607.jpg',
#  'train_data/water\\SeaLake_1608.jpg',
#  'train_data/water\\SeaLake_1610.jpg',
#  'train_data/water\\SeaLake_1611.jpg',
#  'train_data/water\\SeaLake_1612.jpg',
#  'train_data/water\\SeaLake_1614.jpg',
#  'train_data/water\\SeaLake_1615.jpg',
#  'train_data/water\\SeaLake_1616.jpg',
#  'train_data/water\\SeaLake_1619.jpg',
#  'train_data/water\\SeaLake_1620.jpg',
#  'train_data/water\\SeaLake_1622.jpg',
#  'train_data/water\\SeaLake_1627.jpg',
#  'train_data/water\\SeaLake_1629.jpg',
#  'train_data/water\\SeaLake_1630.jpg',
#  'train_data/water\\SeaLake_1631.jpg',
#  'train_data/water\\SeaLake_1633.jpg',
#  'train_data/water\\SeaLake_1634.jpg',
#  'train_data/water\\SeaLake_1636.jpg',
#  'train_data/water\\SeaLake_1637.jpg',
#  'train_data/water\\SeaLake_1641.jpg',
#  'train_data/water\\SeaLake_1643.jpg',
#  'train_data/water\\SeaLake_1644.jpg',
#  'train_data/water\\SeaLake_1645.jpg',
#  'train_data/water\\SeaLake_1646.jpg',
#  'train_data/water\\SeaLake_1650.jpg',
#  'train_data/water\\SeaLake_1651.jpg',
#  'train_data/water\\SeaLake_1653.jpg',
#  'train_data/water\\SeaLake_1654.jpg',
#  'train_data/water\\SeaLake_1657.jpg',
#  'train_data/water\\SeaLake_1659.jpg',
#  'train_data/water\\SeaLake_1661.jpg',
#  'train_data/water\\SeaLake_1665.jpg',
#  'train_data/water\\SeaLake_1666.jpg',
#  'train_data/water\\SeaLake_1667.jpg',
#  'train_data/water\\SeaLake_1672.jpg',
#  'train_data/water\\SeaLake_1674.jpg',
#  'train_data/water\\SeaLake_1676.jpg',
#  'train_data/water\\SeaLake_1679.jpg',
#  'train_data/water\\SeaLake_1680.jpg',
#  'train_data/water\\SeaLake_1686.jpg',
#  'train_data/water\\SeaLake_1688.jpg',
#  'train_data/water\\SeaLake_1691.jpg',
#  'train_data/water\\SeaLake_1692.jpg',
#  'train_data/water\\SeaLake_1694.jpg',
#  'train_data/water\\SeaLake_1695.jpg',
#  'train_data/water\\SeaLake_1697.jpg',
#  'train_data/water\\SeaLake_1698.jpg',
#  'train_data/water\\SeaLake_1699.jpg',
#  'train_data/water\\SeaLake_1700.jpg',
#  'train_data/water\\SeaLake_1701.jpg',
#  'train_data/water\\SeaLake_1702.jpg',
#  'train_data/water\\SeaLake_1703.jpg',
#  'train_data/water\\SeaLake_1704.jpg',
#  'train_data/water\\SeaLake_1705.jpg',
#  'train_data/water\\SeaLake_1707.jpg',
#  'train_data/water\\SeaLake_1713.jpg',
#  'train_data/water\\SeaLake_1715.jpg',
#  'train_data/water\\SeaLake_1719.jpg',
#  'train_data/water\\SeaLake_1720.jpg',
#  'train_data/water\\SeaLake_1727.jpg',
#  'train_data/water\\SeaLake_1728.jpg',
#  'train_data/water\\SeaLake_1729.jpg',
#  'train_data/water\\SeaLake_1733.jpg',
#  'train_data/water\\SeaLake_1736.jpg',
#  'train_data/water\\SeaLake_1737.jpg',
#  'train_data/water\\SeaLake_1740.jpg',
#  'train_data/water\\SeaLake_1741.jpg',
#  'train_data/water\\SeaLake_1744.jpg',
#  'train_data/water\\SeaLake_1745.jpg',
#  'train_data/water\\SeaLake_1749.jpg',
#  'train_data/water\\SeaLake_1751.jpg',
#  'train_data/water\\SeaLake_1752.jpg',
#  'train_data/water\\SeaLake_1754.jpg',
#  'train_data/water\\SeaLake_1757.jpg',
#  'train_data/water\\SeaLake_1759.jpg',
#  'train_data/water\\SeaLake_1763.jpg',
#  'train_data/water\\SeaLake_1765.jpg',
#  'train_data/water\\SeaLake_1766.jpg',
#  'train_data/water\\SeaLake_1769.jpg',
#  'train_data/water\\SeaLake_1770.jpg',
#  'train_data/water\\SeaLake_1772.jpg',
#  'train_data/water\\SeaLake_1774.jpg',
#  'train_data/water\\SeaLake_1776.jpg',
#  'train_data/water\\SeaLake_1777.jpg',
#  'train_data/water\\SeaLake_1782.jpg',
#  'train_data/water\\SeaLake_1785.jpg',
#  'train_data/water\\SeaLake_1786.jpg',
#  'train_data/water\\SeaLake_1788.jpg',
#  'train_data/water\\SeaLake_1789.jpg',
#  'train_data/water\\SeaLake_1792.jpg',
#  'train_data/water\\SeaLake_1800.jpg',
#  'train_data/water\\SeaLake_1802.jpg',
#  'train_data/water\\SeaLake_1804.jpg',
#  'train_data/water\\SeaLake_1808.jpg',
#  'train_data/water\\SeaLake_1809.jpg',
#  'train_data/water\\SeaLake_1810.jpg',
#  'train_data/water\\SeaLake_1818.jpg',
#  'train_data/water\\SeaLake_1819.jpg',
#  'train_data/water\\SeaLake_1820.jpg',
#  'train_data/water\\SeaLake_1823.jpg',
#  'train_data/water\\SeaLake_1824.jpg',
#  'train_data/water\\SeaLake_1828.jpg',
#  'train_data/water\\SeaLake_1829.jpg',
#  'train_data/water\\SeaLake_1830.jpg',
#  'train_data/water\\SeaLake_1834.jpg',
#  'train_data/water\\SeaLake_1839.jpg',
#  'train_data/water\\SeaLake_1840.jpg',
#  'train_data/water\\SeaLake_1843.jpg',
#  'train_data/water\\SeaLake_1845.jpg',
#  'train_data/water\\SeaLake_1846.jpg',
#  'train_data/water\\SeaLake_1847.jpg',
#  'train_data/water\\SeaLake_1848.jpg',
#  'train_data/water\\SeaLake_1855.jpg',
#  'train_data/water\\SeaLake_1856.jpg',
#  'train_data/water\\SeaLake_1858.jpg',
#  'train_data/water\\SeaLake_1860.jpg',
#  'train_data/water\\SeaLake_1867.jpg',
#  'train_data/water\\SeaLake_1868.jpg',
#  'train_data/water\\SeaLake_1870.jpg',
#  'train_data/water\\SeaLake_1874.jpg',
#  'train_data/water\\SeaLake_1877.jpg',
#  'train_data/water\\SeaLake_1881.jpg',
#  'train_data/water\\SeaLake_1884.jpg',
#  'train_data/water\\SeaLake_1886.jpg',
#  'train_data/water\\SeaLake_1888.jpg',
#  'train_data/water\\SeaLake_1895.jpg',
#  'train_data/water\\SeaLake_1896.jpg',
#  'train_data/water\\SeaLake_1902.jpg',
#  'train_data/water\\SeaLake_1903.jpg',
#  'train_data/water\\SeaLake_1911.jpg',
#  'train_data/water\\SeaLake_1916.jpg',
#  'train_data/water\\SeaLake_1919.jpg',
#  'train_data/water\\SeaLake_1920.jpg',
#  'train_data/water\\SeaLake_1926.jpg',
#  'train_data/water\\SeaLake_1930.jpg',
#  'train_data/water\\SeaLake_1933.jpg',
#  'train_data/water\\SeaLake_1934.jpg',
#  'train_data/water\\SeaLake_1935.jpg',
#  'train_data/water\\SeaLake_1938.jpg',
#  'train_data/water\\SeaLake_1939.jpg',
#  'train_data/water\\SeaLake_1940.jpg',
#  'train_data/water\\SeaLake_1941.jpg',
#  'train_data/water\\SeaLake_1942.jpg',
#  'train_data/water\\SeaLake_1944.jpg',
#  'train_data/water\\SeaLake_1947.jpg',
#  'train_data/water\\SeaLake_1953.jpg',
#  'train_data/water\\SeaLake_1954.jpg',
#  'train_data/water\\SeaLake_1958.jpg',
#  'train_data/water\\SeaLake_1961.jpg',
#  'train_data/water\\SeaLake_1962.jpg',
#  'train_data/water\\SeaLake_1964.jpg',
#  'train_data/water\\SeaLake_1967.jpg',
#  'train_data/water\\SeaLake_1974.jpg',
#  'train_data/water\\SeaLake_1975.jpg',
#  'train_data/water\\SeaLake_1976.jpg',
#  'train_data/water\\SeaLake_1977.jpg',
#  'train_data/water\\SeaLake_1982.jpg',
#  'train_data/water\\SeaLake_1983.jpg',
#  'train_data/water\\SeaLake_1985.jpg',
#  'train_data/water\\SeaLake_1990.jpg',
#  'train_data/water\\SeaLake_1993.jpg',
#  'train_data/water\\SeaLake_1997.jpg',
#  'train_data/water\\SeaLake_1998.jpg',
#  'train_data/water\\SeaLake_2000.jpg',
#  'train_data/water\\SeaLake_2001.jpg',
#  'train_data/water\\SeaLake_2003.jpg',
#  'train_data/water\\SeaLake_2008.jpg',
#  'train_data/water\\SeaLake_2011.jpg',
#  'train_data/water\\SeaLake_2012.jpg',
#  'train_data/water\\SeaLake_2016.jpg',
#  'train_data/water\\SeaLake_2018.jpg',
#  'train_data/water\\SeaLake_2022.jpg',
#  'train_data/water\\SeaLake_2023.jpg',
#  'train_data/water\\SeaLake_2028.jpg',
#  'train_data/water\\SeaLake_2029.jpg',
#  'train_data/water\\SeaLake_2031.jpg',
#  'train_data/water\\SeaLake_2037.jpg',
#  'train_data/water\\SeaLake_2038.jpg',
#  'train_data/water\\SeaLake_2040.jpg',
#  'train_data/water\\SeaLake_2041.jpg',
#  'train_data/water\\SeaLake_2044.jpg',
#  'train_data/water\\SeaLake_2046.jpg',
#  'train_data/water\\SeaLake_2047.jpg',
#  'train_data/water\\SeaLake_2049.jpg',
#  'train_data/water\\SeaLake_2055.jpg',
#  'train_data/water\\SeaLake_2059.jpg',
#  'train_data/water\\SeaLake_2062.jpg',
#  'train_data/water\\SeaLake_2063.jpg',
#  'train_data/water\\SeaLake_2065.jpg',
#  'train_data/water\\SeaLake_2066.jpg',
#  'train_data/water\\SeaLake_2070.jpg',
#  'train_data/water\\SeaLake_2077.jpg',
#  'train_data/water\\SeaLake_2078.jpg',
#  'train_data/water\\SeaLake_2081.jpg',
#  'train_data/water\\SeaLake_2086.jpg',
#  'train_data/water\\SeaLake_2087.jpg',
#  'train_data/water\\SeaLake_2088.jpg',
#  'train_data/water\\SeaLake_2094.jpg',
#  'train_data/water\\SeaLake_2098.jpg',
#  'train_data/water\\SeaLake_2107.jpg',
#  'train_data/water\\SeaLake_2110.jpg',
#  'train_data/water\\SeaLake_2111.jpg',
#  'train_data/water\\SeaLake_2113.jpg',
#  'train_data/water\\SeaLake_2120.jpg',
#  'train_data/water\\SeaLake_2121.jpg',
#  'train_data/water\\SeaLake_2134.jpg',
#  'train_data/water\\SeaLake_2135.jpg',
#  'train_data/water\\SeaLake_2136.jpg',
#  'train_data/water\\SeaLake_2140.jpg',
#  'train_data/water\\SeaLake_2142.jpg',
#  'train_data/water\\SeaLake_2144.jpg',
#  'train_data/water\\SeaLake_2146.jpg',
#  'train_data/water\\SeaLake_2148.jpg',
#  'train_data/water\\SeaLake_2150.jpg',
#  'train_data/water\\SeaLake_2151.jpg',
#  'train_data/water\\SeaLake_2154.jpg',
#  'train_data/water\\SeaLake_2156.jpg',
#  'train_data/water\\SeaLake_2159.jpg',
#  'train_data/water\\SeaLake_2160.jpg',
#  'train_data/water\\SeaLake_2161.jpg',
#  'train_data/water\\SeaLake_2162.jpg',
#  'train_data/water\\SeaLake_2166.jpg',
#  'train_data/water\\SeaLake_2167.jpg',
#  'train_data/water\\SeaLake_2168.jpg',
#  'train_data/water\\SeaLake_2172.jpg',
#  'train_data/water\\SeaLake_2173.jpg',
#  'train_data/water\\SeaLake_2175.jpg',
#  'train_data/water\\SeaLake_2176.jpg',
#  'train_data/water\\SeaLake_2179.jpg',
#  'train_data/water\\SeaLake_2181.jpg',
#  'train_data/water\\SeaLake_2182.jpg',
#  'train_data/water\\SeaLake_2188.jpg',
#  'train_data/water\\SeaLake_2190.jpg',
#  'train_data/water\\SeaLake_2191.jpg',
#  'train_data/water\\SeaLake_2194.jpg',
#  'train_data/water\\SeaLake_2199.jpg',
#  'train_data/water\\SeaLake_2200.jpg',
#  'train_data/water\\SeaLake_2201.jpg',
#  'train_data/water\\SeaLake_2207.jpg',
#  'train_data/water\\SeaLake_2209.jpg',
#  'train_data/water\\SeaLake_2210.jpg',
#  'train_data/water\\SeaLake_2211.jpg',
#  'train_data/water\\SeaLake_2214.jpg',
#  'train_data/water\\SeaLake_2215.jpg',
#  'train_data/water\\SeaLake_2219.jpg',
#  'train_data/water\\SeaLake_2221.jpg',
#  'train_data/water\\SeaLake_2222.jpg',
#  'train_data/water\\SeaLake_2225.jpg',
#  'train_data/water\\SeaLake_2226.jpg',
#  'train_data/water\\SeaLake_2229.jpg',
#  'train_data/water\\SeaLake_2230.jpg',
#  'train_data/water\\SeaLake_2231.jpg',
#  'train_data/water\\SeaLake_2232.jpg',
#  'train_data/water\\SeaLake_2236.jpg',
#  'train_data/water\\SeaLake_2240.jpg',
#  'train_data/water\\SeaLake_2243.jpg',
#  'train_data/water\\SeaLake_2244.jpg',
#  'train_data/water\\SeaLake_2247.jpg',
#  'train_data/water\\SeaLake_2254.jpg',
#  'train_data/water\\SeaLake_2255.jpg',
#  'train_data/water\\SeaLake_2256.jpg',
#  'train_data/water\\SeaLake_2258.jpg',
#  'train_data/water\\SeaLake_2262.jpg',
#  'train_data/water\\SeaLake_2263.jpg',
#  'train_data/water\\SeaLake_2266.jpg',
#  'train_data/water\\SeaLake_2267.jpg',
#  'train_data/water\\SeaLake_2269.jpg',
#  'train_data/water\\SeaLake_2270.jpg',
#  'train_data/water\\SeaLake_2275.jpg',
#  'train_data/water\\SeaLake_2276.jpg',
#  'train_data/water\\SeaLake_2277.jpg',
#  'train_data/water\\SeaLake_2279.jpg',
#  'train_data/water\\SeaLake_2280.jpg',
#  'train_data/water\\SeaLake_2286.jpg',
#  'train_data/water\\SeaLake_2287.jpg',
#  'train_data/water\\SeaLake_2288.jpg',
#  'train_data/water\\SeaLake_2291.jpg',
#  'train_data/water\\SeaLake_2292.jpg',
#  'train_data/water\\SeaLake_2293.jpg',
#  'train_data/water\\SeaLake_2297.jpg',
#  'train_data/water\\SeaLake_2298.jpg',
#  'train_data/water\\SeaLake_2300.jpg',
#  'train_data/water\\SeaLake_2306.jpg',
#  'train_data/water\\SeaLake_2311.jpg',
#  'train_data/water\\SeaLake_2314.jpg',
#  'train_data/water\\SeaLake_2315.jpg',
#  'train_data/water\\SeaLake_2316.jpg',
#  'train_data/water\\SeaLake_2320.jpg',
#  'train_data/water\\SeaLake_2321.jpg',
#  'train_data/water\\SeaLake_2325.jpg',
#  'train_data/water\\SeaLake_2327.jpg',
#  'train_data/water\\SeaLake_2329.jpg',
#  'train_data/water\\SeaLake_2333.jpg',
#  'train_data/water\\SeaLake_2336.jpg',
#  'train_data/water\\SeaLake_2339.jpg',
#  'train_data/water\\SeaLake_2340.jpg',
#  'train_data/water\\SeaLake_2344.jpg',
#  'train_data/water\\SeaLake_2345.jpg',
#  'train_data/water\\SeaLake_2346.jpg',
#  'train_data/water\\SeaLake_2347.jpg',
#  'train_data/water\\SeaLake_2348.jpg',
#  'train_data/water\\SeaLake_2351.jpg',
#  'train_data/water\\SeaLake_2358.jpg',
#  'train_data/water\\SeaLake_2359.jpg',
#  'train_data/water\\SeaLake_2362.jpg',
#  'train_data/water\\SeaLake_2363.jpg',
#  'train_data/water\\SeaLake_2364.jpg',
#  'train_data/water\\SeaLake_2365.jpg',
#  'train_data/water\\SeaLake_2366.jpg',
#  'train_data/water\\SeaLake_2370.jpg',
#  'train_data/water\\SeaLake_2372.jpg',
#  'train_data/water\\SeaLake_2375.jpg',
#  'train_data/water\\SeaLake_2376.jpg',
#  'train_data/water\\SeaLake_2377.jpg',
#  'train_data/water\\SeaLake_2378.jpg',
#  'train_data/water\\SeaLake_2379.jpg',
#  'train_data/water\\SeaLake_2380.jpg',
#  'train_data/water\\SeaLake_2381.jpg',
#  'train_data/water\\SeaLake_2382.jpg',
#  'train_data/water\\SeaLake_2384.jpg',
#  'train_data/water\\SeaLake_2385.jpg',
#  'train_data/water\\SeaLake_2386.jpg',
#  'train_data/water\\SeaLake_2392.jpg',
#  'train_data/water\\SeaLake_2394.jpg',
#  'train_data/water\\SeaLake_2401.jpg',
#  'train_data/water\\SeaLake_2402.jpg',
#  'train_data/water\\SeaLake_2403.jpg',
#  'train_data/water\\SeaLake_2404.jpg',
#  'train_data/water\\SeaLake_2408.jpg',
#  'train_data/water\\SeaLake_2416.jpg',
#  'train_data/water\\SeaLake_2417.jpg',
#  'train_data/water\\SeaLake_2424.jpg',
#  'train_data/water\\SeaLake_2428.jpg',
#  'train_data/water\\SeaLake_2435.jpg',
#  'train_data/water\\SeaLake_2437.jpg',
#  'train_data/water\\SeaLake_2441.jpg',
#  'train_data/water\\SeaLake_2443.jpg',
#  'train_data/water\\SeaLake_2445.jpg',
#  'train_data/water\\SeaLake_2446.jpg',
#  'train_data/water\\SeaLake_2447.jpg',
#  'train_data/water\\SeaLake_2452.jpg',
#  'train_data/water\\SeaLake_2460.jpg',
#  'train_data/water\\SeaLake_2464.jpg',
#  'train_data/water\\SeaLake_2465.jpg',
#  'train_data/water\\SeaLake_2467.jpg',
#  'train_data/water\\SeaLake_2468.jpg',
#  'train_data/water\\SeaLake_2471.jpg',
#  'train_data/water\\SeaLake_2473.jpg',
#  'train_data/water\\SeaLake_2474.jpg',
#  'train_data/water\\SeaLake_2478.jpg',
#  'train_data/water\\SeaLake_2480.jpg',
#  'train_data/water\\SeaLake_2483.jpg',
#  'train_data/water\\SeaLake_2485.jpg',
#  'train_data/water\\SeaLake_2491.jpg',
#  'train_data/water\\SeaLake_2493.jpg',
#  'train_data/water\\SeaLake_2494.jpg',
#  'train_data/water\\SeaLake_2496.jpg',
#  'train_data/water\\SeaLake_2499.jpg',
#  'train_data/water\\SeaLake_2505.jpg',
#  'train_data/water\\SeaLake_2506.jpg',
#  'train_data/water\\SeaLake_2507.jpg',
#  'train_data/water\\SeaLake_2511.jpg',
#  'train_data/water\\SeaLake_2514.jpg',
#  'train_data/water\\SeaLake_2516.jpg',
#  'train_data/water\\SeaLake_2517.jpg',
#  'train_data/water\\SeaLake_2518.jpg',
#  'train_data/water\\SeaLake_2521.jpg',
#  'train_data/water\\SeaLake_2522.jpg',
#  'train_data/water\\SeaLake_2524.jpg',
#  'train_data/water\\SeaLake_2527.jpg',
#  'train_data/water\\SeaLake_2528.jpg',
#  'train_data/water\\SeaLake_2529.jpg',
#  'train_data/water\\SeaLake_2530.jpg',
#  'train_data/water\\SeaLake_2531.jpg',
#  'train_data/water\\SeaLake_2532.jpg',
#  'train_data/water\\SeaLake_2534.jpg',
#  'train_data/water\\SeaLake_2537.jpg',
#  'train_data/water\\SeaLake_2538.jpg',
#  'train_data/water\\SeaLake_2544.jpg',
#  'train_data/water\\SeaLake_2546.jpg',
#  'train_data/water\\SeaLake_2548.jpg',
#  'train_data/water\\SeaLake_2550.jpg',
#  'train_data/water\\SeaLake_2553.jpg',
#  'train_data/water\\SeaLake_2558.jpg',
#  'train_data/water\\SeaLake_2560.jpg',
#  'train_data/water\\SeaLake_2566.jpg',
#  'train_data/water\\SeaLake_2568.jpg',
#  'train_data/water\\SeaLake_2575.jpg',
#  'train_data/water\\SeaLake_2578.jpg',
#  'train_data/water\\SeaLake_2581.jpg',
#  'train_data/water\\SeaLake_2585.jpg',
#  'train_data/water\\SeaLake_2586.jpg',
#  'train_data/water\\SeaLake_2591.jpg',
#  'train_data/water\\SeaLake_2592.jpg',
#  'train_data/water\\SeaLake_2594.jpg',
#  'train_data/water\\SeaLake_2596.jpg',
#  'train_data/water\\SeaLake_2600.jpg',
#  'train_data/water\\SeaLake_2601.jpg',
#  'train_data/water\\SeaLake_2605.jpg',
#  'train_data/water\\SeaLake_2606.jpg',
#  'train_data/water\\SeaLake_2611.jpg',
#  'train_data/water\\SeaLake_2612.jpg',
#  'train_data/water\\SeaLake_2616.jpg',
#  'train_data/water\\SeaLake_2617.jpg',
#  'train_data/water\\SeaLake_2618.jpg',
#  'train_data/water\\SeaLake_2619.jpg',
#  'train_data/water\\SeaLake_2623.jpg',
#  'train_data/water\\SeaLake_2624.jpg',
#  'train_data/water\\SeaLake_2626.jpg',
#  'train_data/water\\SeaLake_2628.jpg',
#  'train_data/water\\SeaLake_2635.jpg',
#  'train_data/water\\SeaLake_2636.jpg',
#  'train_data/water\\SeaLake_2637.jpg',
#  'train_data/water\\SeaLake_2638.jpg',
#  'train_data/water\\SeaLake_2641.jpg',
#  'train_data/water\\SeaLake_2642.jpg',
#  'train_data/water\\SeaLake_2643.jpg',
#  'train_data/water\\SeaLake_2645.jpg',
#  'train_data/water\\SeaLake_2647.jpg',
#  'train_data/water\\SeaLake_2651.jpg',
#  'train_data/water\\SeaLake_2653.jpg',
#  'train_data/water\\SeaLake_2654.jpg',
#  'train_data/water\\SeaLake_2657.jpg',
#  'train_data/water\\SeaLake_2659.jpg',
#  'train_data/water\\SeaLake_2660.jpg',
#  'train_data/water\\SeaLake_2663.jpg',
#  'train_data/water\\SeaLake_2669.jpg',
#  'train_data/water\\SeaLake_2672.jpg',
#  'train_data/water\\SeaLake_2673.jpg',
#  'train_data/water\\SeaLake_2679.jpg',
#  'train_data/water\\SeaLake_2685.jpg',
#  'train_data/water\\SeaLake_2688.jpg',
#  'train_data/water\\SeaLake_2690.jpg',
#  'train_data/water\\SeaLake_2692.jpg',
#  'train_data/water\\SeaLake_2694.jpg',
#  'train_data/water\\SeaLake_2695.jpg',
#  'train_data/water\\SeaLake_2696.jpg',
#  'train_data/water\\SeaLake_2699.jpg',
#  'train_data/water\\SeaLake_2702.jpg',
#  'train_data/water\\SeaLake_2704.jpg',
#  'train_data/water\\SeaLake_2705.jpg',
#  'train_data/water\\SeaLake_2719.jpg',
#  'train_data/water\\SeaLake_2721.jpg',
#  'train_data/water\\SeaLake_2724.jpg',
#  'train_data/water\\SeaLake_2726.jpg',
#  'train_data/water\\SeaLake_2727.jpg',
#  'train_data/water\\SeaLake_2728.jpg',
#  'train_data/water\\SeaLake_2729.jpg',
#  'train_data/water\\SeaLake_2730.jpg',
#  'train_data/water\\SeaLake_2732.jpg',
#  'train_data/water\\SeaLake_2733.jpg',
#  'train_data/water\\SeaLake_2737.jpg',
#  'train_data/water\\SeaLake_2738.jpg',
#  'train_data/water\\SeaLake_2742.jpg',
#  'train_data/water\\SeaLake_2746.jpg',
#  'train_data/water\\SeaLake_2749.jpg',
#  'train_data/water\\SeaLake_2751.jpg',
#  'train_data/water\\SeaLake_2753.jpg',
#  'train_data/water\\SeaLake_2755.jpg',
#  'train_data/water\\SeaLake_2756.jpg',
#  'train_data/water\\SeaLake_2757.jpg',
#  'train_data/water\\SeaLake_2760.jpg',
#  'train_data/water\\SeaLake_2763.jpg',
#  'train_data/water\\SeaLake_2767.jpg',
#  'train_data/water\\SeaLake_2771.jpg',
#  'train_data/water\\SeaLake_2772.jpg',
#  'train_data/water\\SeaLake_2773.jpg',
#  'train_data/water\\SeaLake_2775.jpg',
#  'train_data/water\\SeaLake_2779.jpg',
#  'train_data/water\\SeaLake_2780.jpg',
#  'train_data/water\\SeaLake_2783.jpg',
#  'train_data/water\\SeaLake_2785.jpg',
#  'train_data/water\\SeaLake_2786.jpg',
#  'train_data/water\\SeaLake_2788.jpg',
#  'train_data/water\\SeaLake_2789.jpg',
#  'train_data/water\\SeaLake_2793.jpg',
#  'train_data/water\\SeaLake_2794.jpg',
#  'train_data/water\\SeaLake_2795.jpg',
#  'train_data/water\\SeaLake_2799.jpg',
#  'train_data/water\\SeaLake_2802.jpg',
#  'train_data/water\\SeaLake_2806.jpg',
#  'train_data/water\\SeaLake_2807.jpg',
#  'train_data/water\\SeaLake_2808.jpg',
#  'train_data/water\\SeaLake_2809.jpg',
#  'train_data/water\\SeaLake_2813.jpg',
#  'train_data/water\\SeaLake_2814.jpg',
#  'train_data/water\\SeaLake_2815.jpg',
#  'train_data/water\\SeaLake_2817.jpg',
#  'train_data/water\\SeaLake_2818.jpg',
#  'train_data/water\\SeaLake_2819.jpg',
#  'train_data/water\\SeaLake_2820.jpg',
#  'train_data/water\\SeaLake_2824.jpg',
#  'train_data/water\\SeaLake_2825.jpg',
#  'train_data/water\\SeaLake_2826.jpg',
#  'train_data/water\\SeaLake_2827.jpg',
#  'train_data/water\\SeaLake_2828.jpg',
#  'train_data/water\\SeaLake_2829.jpg',
#  'train_data/water\\SeaLake_2830.jpg',
#  'train_data/water\\SeaLake_2832.jpg',
#  'train_data/water\\SeaLake_2833.jpg',
#  'train_data/water\\SeaLake_2839.jpg',
#  'train_data/water\\SeaLake_2841.jpg',
#  'train_data/water\\SeaLake_2843.jpg',
#  'train_data/water\\SeaLake_2844.jpg',
#  'train_data/water\\SeaLake_2845.jpg',
#  'train_data/water\\SeaLake_2849.jpg',
#  'train_data/water\\SeaLake_2851.jpg',
#  'train_data/water\\SeaLake_2852.jpg',
#  'train_data/water\\SeaLake_2854.jpg',
#  'train_data/water\\SeaLake_2857.jpg',
#  'train_data/water\\SeaLake_2858.jpg',
#  'train_data/water\\SeaLake_2859.jpg',
#  'train_data/water\\SeaLake_2861.jpg',
#  'train_data/water\\SeaLake_2863.jpg',
#  'train_data/water\\SeaLake_2864.jpg',
#  'train_data/water\\SeaLake_2867.jpg',
#  'train_data/water\\SeaLake_2873.jpg',
#  'train_data/water\\SeaLake_2874.jpg',
#  'train_data/water\\SeaLake_2878.jpg',
#  'train_data/water\\SeaLake_2882.jpg',
#  'train_data/water\\SeaLake_2884.jpg',
#  'train_data/water\\SeaLake_2885.jpg',
#  'train_data/water\\SeaLake_2887.jpg',
#  'train_data/water\\SeaLake_2891.jpg',
#  'train_data/water\\SeaLake_2892.jpg',
#  'train_data/water\\SeaLake_2894.jpg',
#  'train_data/water\\SeaLake_2895.jpg',
#  'train_data/water\\SeaLake_2897.jpg',
#  'train_data/water\\SeaLake_2898.jpg',
#  'train_data/water\\SeaLake_2900.jpg',
#  'train_data/water\\SeaLake_2904.jpg',
#  'train_data/water\\SeaLake_2905.jpg',
#  'train_data/water\\SeaLake_2906.jpg',
#  'train_data/water\\SeaLake_2908.jpg',
#  'train_data/water\\SeaLake_2909.jpg',
#  'train_data/water\\SeaLake_2915.jpg',
#  'train_data/water\\SeaLake_2918.jpg',
#  'train_data/water\\SeaLake_2919.jpg',
#  'train_data/water\\SeaLake_2922.jpg',
#  'train_data/water\\SeaLake_2923.jpg',
#  'train_data/water\\SeaLake_2924.jpg',
#  'train_data/water\\SeaLake_2925.jpg',
#  'train_data/water\\SeaLake_2926.jpg',
#  'train_data/water\\SeaLake_2928.jpg',
#  'train_data/water\\SeaLake_2929.jpg',
#  'train_data/water\\SeaLake_2932.jpg',
#  'train_data/water\\SeaLake_2935.jpg',
#  'train_data/water\\SeaLake_2936.jpg',
#  'train_data/water\\SeaLake_2937.jpg',
#  'train_data/water\\SeaLake_2940.jpg',
#  'train_data/water\\SeaLake_2941.jpg',
#  'train_data/water\\SeaLake_2946.jpg',
#  'train_data/water\\SeaLake_2949.jpg',
#  'train_data/water\\SeaLake_2950.jpg',
#  'train_data/water\\SeaLake_2953.jpg',
#  'train_data/water\\SeaLake_2955.jpg',
#  'train_data/water\\SeaLake_2957.jpg',
#  'train_data/water\\SeaLake_2958.jpg',
#  'train_data/water\\SeaLake_2960.jpg',
#  'train_data/water\\SeaLake_2962.jpg',
#  'train_data/water\\SeaLake_2972.jpg',
#  'train_data/water\\SeaLake_2974.jpg',
#  'train_data/water\\SeaLake_2975.jpg',
#  'train_data/water\\SeaLake_2976.jpg',
#  'train_data/water\\SeaLake_2979.jpg',
#  'train_data/water\\SeaLake_2980.jpg',
#  'train_data/water\\SeaLake_2981.jpg',
#  'train_data/water\\SeaLake_2989.jpg',
#  'train_data/water\\SeaLake_2990.jpg',
#  'train_data/water\\SeaLake_2995.jpg',
#  'train_data/water\\SeaLake_2999.jpg',
#  'train_data/water\\SeaLake_3000.jpg']

# %% [markdown]
# #### Fetch the testing data

# %%
cloudy_test = glob.glob('test_data/cloudy/*.jpg')
desert_test = glob.glob('test_data/desert/*.jpg')
green_area_test = glob.glob('test_data/green_area/*.jpg')
water_test = glob.glob('test_data/water/*.jpg')

# %% [markdown]
# #### Find the number of images of all classes in the Training set

# %%
print(f'Number of cloudy images {len(cloudy)}')
print(f'Number of desert images {len(desert)}')
print(f'Number of green area images {len(green_area)}')
print(f'Number of water images {len(water)}')
# Out:
# Number of cloudy images 807
# Number of desert images 547
# Number of green area images 772
# Number of water images 796

# %% [markdown]
# #### Find the number of images of all classes in the testing set

# %%
print(f'Number of cloudy test images {len(cloudy_test)}')
print(f'Number of desert test images {len(desert_test)}')
print(f'Number of green test area images {len(green_area_test)}')
print(f'Number of water test images {len(water_test)}')
# Out:
# Number of cloudy test images 807
# Number of desert test images 547
# Number of green test area images 772
# Number of water test images 796

# %% [markdown]
# #### Store all the images inside a list and create a list with the corresponding labels

# %% [markdown]
# #### For Training set

# %%
image = []
label = []

for i in cloudy:
    img = plt.imread(i)
    image.append(img)
    label.append(0)

for i in desert:
    img = plt.imread(i)
    image.append(img)
    label.append(1)

for i in green_area:
    img = plt.imread(i)
    image.append(img)
    label.append(2)

for i in water: 
    img = plt.imread(i)
    image.append(img)
    label.append(3)

# %% [markdown]
# #### For Testing set

# %%
image_test = []
label_test = []

for i in cloudy_test: 
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(0)

for i in desert_test: 
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(1)

for i in green_area_test:
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(2)

for i in water_test: 
    img = plt.imread(i)
    image_test.append(img)
    label_test.append(3)

# %% [markdown]
# #### Shuffle both image list and label list (In both Training and testing set)

# %% [markdown]
# ##### Use shuffle function from sklearn utils

# %%
from sklearn.utils import shuffle

# %%
image, label = shuffle(image, label, random_state=100)
image_test, label_test = shuffle(image_test, label_test)

# %%
len(label_test)
# Out:
# 2922

# %% [markdown]
# #### Plot a few images from our shuffled list with its corresponding label (Either from training or test set)

# %%
for i in range(20):
    plt.subplot(4,5, i+1)
    plt.imshow(image[i])

    if label[i] == 0:
        plt.title('cloudy')
    elif label[i] == 1: 
        plt.title('desert')
    elif label[i] == 2:
        plt.title('green area')
    else:
        plt.title('water')
    plt.tight_layout()

# %% [markdown]
# #### Check the shape of the first 10 images in our list (Either from training or test set)

# %%
for i in range(10): 
    print(image[i].shape)
# Out:
# (256, 256, 4)
# (64, 64, 3)
# (256, 256, 4)
# (256, 256, 3)
# (64, 64, 3)
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)
# (64, 64, 3)
# (64, 64, 3)

# %% [markdown]
# #### Reshape the images ( For both training and testing set)

# %% [markdown]
# Also reassign them to new variables named X_train and X_test and convert them to a numpy array

# %%
from skimage.transform import resize

# %%
xtrain = []
for i in image: 
    xtrain.append(resize(i,(256,256,3)))
xtrain = np.array(xtrain)

# %%
xtest = []
for i in image_test: 
    xtest.append(resize(i,(256,256,3)))
xtest = np.array(xtest)

# %% [markdown]
# #### create numpy arrays named y_train and y_test from our training and testing label lists we created earlier

# %%
ytrain = np.array(label)
ytest = np.array(label_test)

# %% [markdown]
# #### Plot some of our reshaped images

# %%
for i in range(20):
    plt.subplot(4, 5, i+1)
    plt.imshow(xtrain[i])
    plt.title(label[i])
    plt.tight_layout()

# %% [markdown]
# #### Check the shape of X_train and X_test and y_train and y_test

# %%
print(f'Shape of xtrain is:',xtrain.shape)
print(f'Shape of xtest is:',xtest.shape)
print(f'Shape of ytrain is:',ytrain.shape)
print(f'Shape of ytest is:',ytest.shape)
# Out:
# Shape of xtrain is: (2922, 256, 256, 3)
# Shape of xtest is: (2922, 256, 256, 3)
# Shape of ytrain is: (2922,)
# Shape of ytest is: (2922,)

# %% [markdown]
# #### Create a keras Sequential model with convolution layers, Flatten and Hidden layers

# %%
from tensorflow import keras

# %%
model = keras.models.Sequential([
    keras.layers.Conv2D(16,(3, 3), activation = 'relu', input_shape = (256,256,3)),
    keras.layers.MaxPool2D(2,2),

    keras.layers.Conv2D(32,(3, 3), activation = 'relu'),
    keras.layers.MaxPool2D(2,2),

    keras.layers.Flatten(),
    keras.layers.Dense(64, activation = 'relu'),
    keras.layers.Dense(4, activation = 'softmax')
])
# Out:
# C:\Users\DHILSHANA SHIRIN\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### Compile the model

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# #### Check the summary of our model

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 62, 62, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 123008)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │       7,872,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │             260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7,877,924 (30.05 MB)
#  Trainable params: 7,877,924 (30.05 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### Train the model.

# %%
model.fit(xtrain, ytrain, epochs = 15, validation_split = 0.1)
# Out:
# Epoch 1/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 50s 465ms/step - accuracy: 0.4287 - loss: 1.9580 - val_accuracy: 0.7406 - val_loss: 0.6268
# Epoch 2/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 40s 481ms/step - accuracy: 0.7603 - loss: 0.5044 - val_accuracy: 0.8328 - val_loss: 0.3842
# Epoch 3/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 45s 544ms/step - accuracy: 0.7690 - loss: 0.5808 - val_accuracy: 0.8908 - val_loss: 0.2750
# Epoch 4/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 38s 451ms/step - accuracy: 0.9027 - loss: 0.2712 - val_accuracy: 0.8874 - val_loss: 0.2647
# Epoch 5/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 417ms/step - accuracy: 0.9052 - loss: 0.2204 - val_accuracy: 0.9215 - val_loss: 0.2025
# Epoch 6/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 399ms/step - accuracy: 0.9141 - loss: 0.2038 - val_accuracy: 0.9078 - val_loss: 0.1958
# Epoch 7/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 398ms/step - accuracy: 0.9110 - loss: 0.1938 - val_accuracy: 0.8908 - val_loss: 0.2967
# Epoch 8/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 425ms/step - accuracy: 0.9177 - loss: 0.1904 - val_accuracy: 0.8908 - val_loss: 0.2478
# Epoch 9/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 398ms/step - accuracy: 0.8992 - loss: 0.2340 - val_accuracy: 0.9147 - val_loss: 0.1796
# Epoch 10/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 400ms/step - accuracy: 0.9199 - loss: 0.1808 - val_accuracy: 0.9283 - val_loss: 0.1713
# Epoch 11/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 393ms/step - accuracy: 0.9253 - loss: 0.1702 - val_accuracy: 0.9044 - val_loss: 0.2119
# Epoch 12/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 394ms/step - accuracy: 0.8933 - loss: 0.2368 - val_accuracy: 0.9249 - val_loss: 0.2065
# Epoch 13/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 392ms/step - accuracy: 0.9261 - loss: 0.1747 - val_accuracy: 0.9317 - val_loss: 0.1718
# Epoch 14/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 33s 396ms/step - accuracy: 0.9270 - loss: 0.1615 - val_accuracy: 0.9215 - val_loss: 0.1685
# Epoch 15/15
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 41s 393ms/step - accuracy: 0.9315 - loss: 0.1615 - val_accuracy: 0.9113 - val_loss: 0.2053

# %% [markdown]
# #### Evaluate the model

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 10s 112ms/step - accuracy: 0.9120 - loss: 0.1877
# [0.19500765204429626, 0.907597541809082]

# %% [markdown]
# #### Make predictions with X_test

# %%
ypred = model.predict(xtest)
# Out:
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 126ms/step

# %% [markdown]
# #### Use np.argmax to fetch indices of max element of the array

# %% [markdown]
# Store the values in a list

# %%
ypred = ypred.argmax(axis=1)

# %% [markdown]
# #### Plot X_test with label from our prediction

# %%
for i in range(20): 
    plt.subplot(4, 5, i+1)
    plt.imshow(xtest[i])
    plt.title(label_test[i])
    plt.tight_layout()

# %% [markdown]
# #### Visualise confusion matrix on a heatmap

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ConfusionMatrixDisplay.from_predictions(ytest, ypred)
